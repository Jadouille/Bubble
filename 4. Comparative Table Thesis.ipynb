# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import scipy as sp
import pickle
from statsmodels.stats.weightstats import ztest
import json
from scipy.stats import kstest, norm, kruskal, chi

# %%
# %run ../Classes/Imbalance_Plotter.py #Load all the Datasets Objects Later
# %run ../Classes/Run_imbalances.py #
# %run ../Classes/Dataset_Double.py #Load all the Datasets Objects Later
# %run ../Classes/xvalidation.py #

# %% [markdown]
# # Norm Cats Snow Bubbles Time 15

# %%
datasets=['Maxi_Eighty', 'Maxi_Eighty5', 'Maxi_Ninety', 'Maxi_Ninety5','Midi_Eighty', 'Midi_Eighty5', 'Midi_Ninety', 'Midi_Ninety5', 'Mini_Eighty', 'Mini_Eighty5', 'Mini_Ninety', 'Mini_Ninety5','Tiny_Eighty', 'Tiny_Eighty5', 'Tiny_Ninety', 'Tiny_Ninety5']

name_experiment='normCats_realSnowBubblesTimes15_ray10bis_RealSmote';
# xvalidations=[{'haberman':[], 'magic':[], 'pulsar':[], 'tictactoe':[],'Maxi':[], 'Midi':[], 'Mini':[], 'Tiny':[]},{'haberman':[], 'magic':[], 'pulsar':[], 'tictactoe':[],'Maxi':[], 'Midi':[], 'Mini':[], 'Tiny':[]},{'haberman':[], 'magic':[], 'pulsar':[], 'tictactoe':[],'Maxi':[], 'Midi':[], 'Mini':[], 'Tiny':[]}];
xvalidations_15times=[{'haberman':[], 'magic':[], 'pulsar':[], 'tictactoe':[], 'Maxi_Eighty':[], 'Maxi_Eighty5':[], 'Maxi_Ninety':[], 'Maxi_Ninety5':[],'Midi_Eighty':[], 'Midi_Eighty5':[], 'Midi_Ninety':[], 'Midi_Ninety5':[], 'Mini_Eighty':[], 'Mini_Eighty5':[], 'Mini_Ninety':[], 'Mini_Ninety5':[],'Tiny_Eighty':[], 'Tiny_Eighty5':[], 'Tiny_Ninety':[], 'Tiny_Ninety5':[]}]

real_datasets=['haberman', 'magic', 'pulsar', 'tictactoe'];
suffixes = ['_svc.py'];

for dataset in datasets:
    for suffix in range(0, len(suffixes)):
        path = '../Algorithms_Scores/'+name_experiment+dataset+suffixes[suffix];
        with open(path, 'rb') as fp:
            xvalidations_15times[suffix][dataset]=pickle.load(fp)
print('simple')
        
suffixes=['_svc.txt']
for dataset in real_datasets:
    for suffix in range(0, len(suffixes)):
        path = '../Algorithms_Scores/experimentdouble_'+dataset+'_'+name_experiment+suffixes[suffix];
        with open(path, 'rb') as fp:
            xvalidations_15times[suffix][dataset]=pickle.load(fp)
print('simple')
# Out:
# simple
# simple

# %% [markdown]
# ## Recalls

# %%
scores_original_mean=[{'haberman':[], 'magic':[], 'pulsar':[], 'tictactoe':[], 'Maxi_Eighty':[], 'Maxi_Eighty5':[], 'Maxi_Ninety':[], 'Maxi_Ninety5':[],'Midi_Eighty':[], 'Midi_Eighty5':[], 'Midi_Ninety':[], 'Midi_Ninety5':[], 'Mini_Eighty':[], 'Mini_Eighty5':[], 'Mini_Ninety':[], 'Mini_Ninety5':[],'Tiny_Eighty':[], 'Tiny_Eighty5':[], 'Tiny_Ninety':[], 'Tiny_Ninety5':[]}]
scores_osbblTimes15_mean=[{'haberman':[], 'magic':[], 'pulsar':[], 'tictactoe':[], 'Maxi_Eighty':[], 'Maxi_Eighty5':[], 'Maxi_Ninety':[], 'Maxi_Ninety5':[],'Midi_Eighty':[], 'Midi_Eighty5':[], 'Midi_Ninety':[], 'Midi_Ninety5':[], 'Mini_Eighty':[], 'Mini_Eighty5':[], 'Mini_Ninety':[], 'Mini_Ninety5':[],'Tiny_Eighty':[], 'Tiny_Eighty5':[], 'Tiny_Ninety':[], 'Tiny_Ninety5':[]}]
scores_smote_mean=[{'haberman':[], 'magic':[], 'pulsar':[], 'tictactoe':[], 'Maxi_Eighty':[], 'Maxi_Eighty5':[], 'Maxi_Ninety':[], 'Maxi_Ninety5':[],'Midi_Eighty':[], 'Midi_Eighty5':[], 'Midi_Ninety':[], 'Midi_Ninety5':[], 'Mini_Eighty':[], 'Mini_Eighty5':[], 'Mini_Ninety':[], 'Mini_Ninety5':[],'Tiny_Eighty':[], 'Tiny_Eighty5':[], 'Tiny_Ninety':[], 'Tiny_Ninety5':[]}]

scores_original_std=[{'haberman':[], 'magic':[], 'pulsar':[], 'tictactoe':[], 'Maxi_Eighty':[], 'Maxi_Eighty5':[], 'Maxi_Ninety':[], 'Maxi_Ninety5':[],'Midi_Eighty':[], 'Midi_Eighty5':[], 'Midi_Ninety':[], 'Midi_Ninety5':[], 'Mini_Eighty':[], 'Mini_Eighty5':[], 'Mini_Ninety':[], 'Mini_Ninety5':[],'Tiny_Eighty':[], 'Tiny_Eighty5':[], 'Tiny_Ninety':[], 'Tiny_Ninety5':[]}]
scores_osbblTimes15_std=[{'haberman':[], 'magic':[], 'pulsar':[], 'tictactoe':[], 'Maxi_Eighty':[], 'Maxi_Eighty5':[], 'Maxi_Ninety':[], 'Maxi_Ninety5':[],'Midi_Eighty':[], 'Midi_Eighty5':[], 'Midi_Ninety':[], 'Midi_Ninety5':[], 'Mini_Eighty':[], 'Mini_Eighty5':[], 'Mini_Ninety':[], 'Mini_Ninety5':[],'Tiny_Eighty':[], 'Tiny_Eighty5':[], 'Tiny_Ninety':[], 'Tiny_Ninety5':[]}]
scores_smote_std=[{'haberman':[], 'magic':[], 'pulsar':[], 'tictactoe':[], 'Maxi_Eighty':[], 'Maxi_Eighty5':[], 'Maxi_Ninety':[], 'Maxi_Ninety5':[],'Midi_Eighty':[], 'Midi_Eighty5':[], 'Midi_Ninety':[], 'Midi_Ninety5':[], 'Mini_Eighty':[], 'Mini_Eighty5':[], 'Mini_Ninety':[], 'Mini_Ninety5':[],'Tiny_Eighty':[], 'Tiny_Eighty5':[], 'Tiny_Ninety':[], 'Tiny_Ninety5':[]}]

datasets=['Maxi_Eighty', 'Maxi_Eighty5', 'Maxi_Ninety', 'Maxi_Ninety5','Midi_Eighty', 'Midi_Eighty5', 'Midi_Ninety', 'Midi_Ninety5', 'Mini_Eighty', 'Mini_Eighty5', 'Mini_Ninety', 'Mini_Ninety5', 'Tiny_Eighty', 'Tiny_Eighty5', 'Tiny_Ninety', 'Tiny_Ninety5','haberman', 'magic', 'pulsar', 'tictactoe']


        
for algorithm in range(0, len(scores_original_mean)):
    i=0;
    for dataset in datasets: #knn - #rf -#sgd - #svc       
        crossvalidation = xvalidations_15times[algorithm][dataset];
        if i==10:
            i=0;
        if i>=0: #Choose from which imbalances
            
            comparativeMeasure = crossvalidation.recalls1; #Choose which measure to compare
#             print(comparativeMesure)
            scores_original_mean[algorithm][dataset].append(np.mean(comparativeMeasure[0]));        
            scores_osbblTimes15_mean[algorithm][dataset].append(np.mean(comparativeMeasure[2]));
            scores_smote_mean[algorithm][dataset].append(np.mean(comparativeMeasure[4]));
           
            scores_original_std[algorithm][dataset].append(np.std(comparativeMeasure[0]));
            scores_osbblTimes15_std[algorithm][dataset].append(np.std(comparativeMeasure[2]));
            scores_smote_std[algorithm][dataset].append(np.std(comparativeMeasure[4]));
            
   
        i+=1

# %%
liste=[scores_original_std, scores_osbblTimes15_std, scores_smote_std];
for std in range(0, len(liste)):
    for algorithm in range(0, len(liste[std])):
        for key in liste[std][algorithm]:
            liste[std][algorithm][key]=str(liste[std][algorithm][key])

# %%
results_svc=pd.DataFrame([scores_original_mean[0],scores_original_std[0],scores_osbblTimes15_mean[0],scores_osbblTimes15_std[0], scores_smote_mean[0], scores_smote_std[0]], index=['Original','std','Bubble','std', 'Smote','std']).transpose()

# %%
name_experiment='all_together_10'

# %%
path='C:/Users/jadec/My Tresors/Maastricht/CBS/Thesis/Code/Boum/classif/Saved-Objects/ResultsTable/'+name_experiment+'_ResultsTable'
results_svc.to_csv(path_or_buf=(path+'svc_recalls.csv'), sep=';')

# %%
maxima=[];
o=[0];
bblTimes15=[0];
s=[0];
oversamplings = ['Oversampling','Bubble Times 15','SMOTE']
alg_names=['DT','KNN', 'RF', 'SGD', 'SVC'];
liste=[scores_original_mean,scores_osbblTimes15_mean,scores_smote_mean];
for algorithm in range(0, len(scores_original_mean)):
    print(alg_names[algorithm])
    maxima.append(alg_names[algorithm]);
    for key in scores_original_mean[algorithm]:
        try:
            points = [scores_original_mean[algorithm][key],scores_osbblTimes15_mean[algorithm][key],scores_smote_mean[algorithm][key]]
            index = np.argmax(points);
            print(points[index])
            maxima.append(oversamplings[index])
            if points[index]==[0]:
                continue
            if index==0:
                o[algorithm]+=1;
            elif index==1:
                bblTimes15[algorithm]+=1
            elif index==2:
                s[algorithm]+=1
        except ValueError:
            continue
# Out:
# DT
# [0.9821428571428571]
# [0.99615439396097438]
# [0.90476190476190477]
# [0.99857142857142855]
# [0.94248304886602774]
# [0.93798210428879969]
# [0.91328160657234136]
# [0.87705627705627698]
# [0.93302107728337236]
# [0.93011750154607309]
# [0.88989990900818938]
# [0.85191637630662032]
# [0.80755608028335291]
# [0.78963893249607531]
# [0.82903981264637017]
# [0.79262672811059909]
# [0.77880184331797242]
# [0.69565217391304335]
# [0.7767857142857143]
# [0.5535714285714286]

# %%
print(alg_names)
print(o)
print(bblTimes15)
print(s)
# Out:
# ['DT', 'KNN', 'RF', 'SGD', 'SVC']
# [0]
# [11]
# [9]

# %%
file = pd.read_csv('C:/Users/jadec/My Tresors/Maastricht/CBS/Thesis/Code/Boum/Classif/Saved-Objects/ResultsTable/all_together_10_ResultsTablesvc_recalls.csv', sep=';',index_col=0,header=0)

# %%
file
# Out:
#                            Original                      std  \
# Maxi_Eighty   [0.81762917933130708]   [0.010492777962271152]
# Maxi_Eighty5  [0.70317803147176783]   [0.014596576578234967]
# Maxi_Ninety   [0.48790506617982654]    [0.03589156230276129]
# Maxi_Ninety5  [0.29437229437229434]   [0.024211483037419154]
# Midi_Eighty   [0.72927400468384085]   [0.024463821746511651]
# Midi_Eighty5   [0.6351267779839207]    [0.02478350638158797]
# Midi_Ninety   [0.53048225659690629]   [0.040814670595096997]
# Midi_Ninety5  [0.45644599303135885]   [0.057147106156295216]
# Mini_Eighty    [0.6564344746162929]   [0.038475019449351423]
# Mini_Eighty5  [0.54631083202511788]   [0.041415717294420458]
# Mini_Ninety    [0.4379391100702576]   [0.045290584556940787]
# Mini_Ninety5   [0.2119815668202765]   [0.074875929996644802]
# Tiny_Eighty   [0.41013824884792627]   [0.056439855824497183]
# Tiny_Eighty5  [0.32298136645962738]    [0.06085688801945785]
# ...

# %%
array=[[],[],[],[],[],[]]
for row in range(0, len(file)):
    for col in range(0, len(file.iloc[row])):
        try:
            print(column, data)
            array[col].append(float((str(file.iloc[row][col])[1:-1])))
        except ValueError:
            continue
# Out:
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0
# 6 0

# %%
pd.DataFrame(array, columns=datasets, index=['Original', 'Original std', 'Bubble', 'Bubble std', 'SMOTE', 'SMOTE std']).transpose()
# Out:
#               Original  Original std    Bubble  Bubble std     SMOTE  \
# Maxi_Eighty   0.817629      0.010493  0.942483    0.006025  0.940145
# Maxi_Eighty5  0.703178      0.014597  0.937982    0.006398  0.936131
# Maxi_Ninety   0.487905      0.035892  0.913282    0.015027  0.911456
# Maxi_Ninety5  0.294372      0.024211  0.874459    0.010604  0.877056
# Midi_Eighty   0.729274      0.024464  0.926932    0.017412  0.933021
# Midi_Eighty5  0.635127      0.024784  0.928262    0.011063  0.930118
# Midi_Ninety   0.530482      0.040815  0.888990    0.022802  0.889900
# Midi_Ninety5  0.456446      0.057147  0.836237    0.014366  0.851916
# Mini_Eighty   0.656434      0.038475  0.807556    0.022832  0.798111
# Mini_Eighty5  0.546311      0.041416  0.788069    0.023285  0.789639
# Mini_Ninety   0.437939      0.045291  0.829040    0.055321  0.814988
# Mini_Ninety5  0.211982      0.074876  0.792627    0.082436  0.778802
# Tiny_Eighty   0.410138      0.056440  0.774194    0.051728  0.778802
# ...
